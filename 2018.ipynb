# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import string
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.probability import FreqDist
import pymorphy3

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
with open('2018.txt', 'r') as file:
    data = file.read()

# %%
stop_words = stopwords.words('russian')
morph = pymorphy3.MorphAnalyzer()

# %%
def tokenize_text(raw_text: str):
    """Функция для токенизации текста
    :param raw_text: исходная текстовая строка
    """
    # Разбиение на сслова при помощи пробела
    words = raw_text.split()
    # Подготовка регулярного выражения для фильтрации символов
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # Удаление знаков препинания
    stripped = [re_punc.sub('', w) for w in words]
    # Приведение всех слов к нижнему регистру
    words_lower = [w.lower() for w in stripped]
    # Удаление оставшихся токенов, которые не являются буквами
    words_alpha = [word for word in words_lower if word.isalpha()]
    # Удаление стоп-слов    
    words_stop = [w for w in words_alpha if not w in stop_words]
    # Лемматизация    
    tokens = [morph.parse(token)[0].normal_form for token in words_stop]
    # Удалим короткие токены
    tokens = [word for word in tokens if len(word) > 2]
      
    return tokens

# %%
tokenized = tokenize_text(data)

# %%
all_words = FreqDist(tokenized)

# %%
print("Наиболлее популярные слова: ", all_words.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words.keys()))
# Out:
# Наиболлее популярные слова:  [('брикс', 207), ('страна', 134), ('год', 103), ('встреча', 91), ('сотрудничество', 70), ('развитие', 67), ('вопрос', 58), ('международный', 51), ('область', 48), ('оон', 47), ('также', 46), ('безопасность', 41), ('цель', 40), ('вновь', 40), ('группа', 38), ('министр', 35), ('приветствовать', 34), ('рамка', 34), ('который', 32), ('рабочий', 32), ('укрепление', 31), ('устойчивый', 29), ('экономический', 28), ('подтверждать', 28), ('признать', 28), ('связь', 28), ('июль', 26), ('сфера', 26), ('форум', 26), ('отмечать', 24), ('подчёркивать', 24), ('создание', 24), ('мир', 23), ('число', 23), ('торговля', 23), ('свой', 22), ('система', 22), ('поддержка', 22), ('обеспечение', 21), ('наш', 21), ('роль', 21), ('призывать', 21), ('июнь', 21), ('дурбан', 21), ('рост', 20), ('право', 20), ('экономика', 19), ('глобальный', 19), ('технология', 19), ('приверженность', 18), ('использование', 18), ('финансовый', 18), ('борьба', 17), ('заявлять', 17), ('совет', 17), ('май', 17), ('организация', 16), ('преторий', 16), ('государство', 15), ('йоханнесбург', 15), ('принцип', 15), ('дальнейший', 15), ('поддерживать', 15), ('национальный', 15), ('промышленный', 14), ('прогресс', 14), ('работа', 14), ('инициатива', 14), ('усилие', 14), ('необходимость', 14), ('икт', 14), ('важный', 13), ('инклюзивный', 13), ('обмен', 13), ('совместный', 13), ('политический', 13), ('многосторонний', 13), ('содействие', 13), ('лицо', 13), ('саммит', 12), ('объединение', 12), ('африка', 12), ('центральный', 12), ('включая', 12), ('деятельность', 12), ('ресурс', 12), ('таможенный', 12), ('проведение', 11), ('заседание', 11), ('потенциал', 11), ('решение', 11), ('значимость', 11), ('африканский', 11), ('важность', 11), ('обязательство', 11), ('соответствующий', 11), ('исследование', 11), ('терроризм', 11), ('новый', 11), ('пространство', 11)]
#
# Общее количество уникальных слов:  1333

# %%
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_2020\1563493910.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
stop_words_ex = ['год','наш', 'который', 'также']
def stop_words_extra(text):
    return [w for w in text if not w in stop_words_ex]

# %%
tokens = stop_words_extra(tokenized)

# %%
all_words = FreqDist(tokens)
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_2020\3051857113.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
textt = ','.join(w for w in tokens)

# %%
wordcloud = WordCloud(width=950,height=550).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Приводим текст в векторное представление
tfidf_vect = TfidfVectorizer(max_df=1.0, min_df=2, stop_words=None)
doc_term_matrix = tfidf_vect.fit_transform(tokens)

# %% [markdown]
# ### Латентное размещение Дерихле

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['устойчивый', 'укрепление', 'министр', 'вновь', 'область', 'международный', 'развитие', 'встреча', 'страна', 'брикс']
#
#
# Top 10 words for topic #1:
# ['подтверждать', 'рабочий', 'приветствовать', 'рамка', 'группа', 'цель', 'безопасность', 'оон', 'вопрос', 'сотрудничество']

# %%
LDA = LatentDirichletAllocation(n_components=3, random_state=42)
LDA.fit(doc_term_matrix)
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['поддержка', 'свой', 'мир', 'июль', 'сфера', 'устойчивый', 'укрепление', 'вновь', 'область', 'страна']
#
#
# Top 10 words for topic #1:
# ['создание', 'форум', 'признать', 'подтверждать', 'рабочий', 'рамка', 'цель', 'оон', 'вопрос', 'сотрудничество']
#
#
# Top 10 words for topic #2:
# ['связь', 'экономический', 'приветствовать', 'министр', 'группа', 'безопасность', 'международный', 'развитие', 'встреча', 'брикс']

# %% [markdown]
# Вывод: тематика декларации 2018 г. посвящена общим вопросам международного сотрудничества. Отдельно африканская тема в повестке саммита не звучала
