# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import string
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.probability import FreqDist
import pymorphy3

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
with open('2015.txt', 'r') as file:
    data = file.read()

# %%
stop_words = stopwords.words('russian')
morph = pymorphy3.MorphAnalyzer()

# %%
def tokenize_text(raw_text: str):
    """Функция для токенизации текста
    :param raw_text: исходная текстовая строка
    """
    # Разбиение на сслова при помощи пробела
    words = raw_text.split()
    # Подготовка регулярного выражения для фильтрации символов
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # Удаление знаков препинания
    stripped = [re_punc.sub('', w) for w in words]
    # Приведение всех слов к нижнему регистру
    words_lower = [w.lower() for w in stripped]
    # Удаление оставшихся токенов, которые не являются буквами
    words_alpha = [word for word in words_lower if word.isalpha()]
    # Удаление стоп-слов    
    words_stop = [w for w in words_alpha if not w in stop_words]
    # Лемматизация    
    tokens = [morph.parse(token)[0].normal_form for token in words_stop]
    # Удалим короткие токены
    tokens = [word for word in tokens if len(word) > 2]
      
    return tokens

# %%
tokenized = tokenize_text(data)

# %%
all_words = FreqDist(tokenized)

# %%
print("Наиболлее популярные слова: ", all_words.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words.keys()))
# Out:
# Наиболлее популярные слова:  [('страна', 126), ('брикс', 114), ('международный', 108), ('развитие', 103), ('сотрудничество', 96), ('также', 82), ('наш', 67), ('цель', 67), ('год', 66), ('область', 61), ('усилие', 55), ('безопасность', 53), ('оон', 51), ('государство', 47), ('связь', 45), ('приветствовать', 43), ('право', 43), ('призывать', 42), ('вопрос', 40), ('который', 39), ('подчёркивать', 39), ('укрепление', 35), ('подтверждать', 35), ('обеспечение', 33), ('принцип', 32), ('экономический', 32), ('сфера', 32), ('устойчивый', 31), ('решение', 29), ('создание', 29), ('организация', 29), ('проблема', 28), ('вновь', 28), ('национальный', 28), ('основа', 27), ('использование', 27), ('технология', 27), ('рамка', 26), ('поддерживать', 25), ('проведение', 25), ('другой', 25), ('глобальный', 24), ('мировой', 24), ('необходимость', 24), ('борьба', 24), ('рост', 23), ('сообщество', 23), ('роль', 23), ('выражать', 23), ('икт', 23), ('интерес', 22), ('мир', 22), ('содействие', 22), ('человек', 22), ('экономика', 22), ('совместный', 21), ('отмечать', 21), ('группа', 21), ('работа', 20), ('уровень', 20), ('направить', 20), ('должный', 20), ('финансовый', 19), ('политический', 19), ('совет', 19), ('важный', 19), ('условие', 19), ('достижение', 19), ('число', 19), ('возможность', 19), ('поддержка', 18), ('мера', 18), ('разработка', 18), ('важность', 17), ('механизм', 17), ('свой', 17), ('угроза', 17), ('соответствующий', 17), ('инновация', 17), ('помощь', 17), ('сторона', 17), ('космический', 17), ('общий', 16), ('отношение', 16), ('новый', 16), ('правительство', 16), ('диалог', 16), ('подход', 16), ('деятельность', 16), ('регион', 16), ('соглашение', 16), ('представлять', 15), ('взаимодействие', 15), ('встреча', 15), ('приверженность', 15), ('эффективный', 15), ('потенциал', 15), ('координация', 15), ('политика', 15), ('мирный', 15)]
#
# Общее количество уникальных слов:  1769

# %%
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_11284\1563493910.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
stop_words_ex = ['год','наш', 'который', 'также']
def stop_words_extra(text):
    return [w for w in text if not w in stop_words_ex]

# %%
tokens = stop_words_extra(tokenized)

# %%
all_words = FreqDist(tokens)
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_11284\3051857113.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
textt = ','.join(w for w in tokens)

# %%
wordcloud = WordCloud(width=950,height=550).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Приводим текст в векторное представление
tfidf_vect = TfidfVectorizer(max_df=1.0, min_df=2, stop_words=None)
doc_term_matrix = tfidf_vect.fit_transform(tokens)

# %% [markdown]
# ### Латентное размещение Дерихле

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['основа', 'использование', 'вновь', 'решение', 'устойчивый', 'экономический', 'подчёркивать', 'право', 'область', 'развитие']
#
#
# Top 10 words for topic #1:
# ['связь', 'государство', 'оон', 'безопасность', 'усилие', 'цель', 'сотрудничество', 'международный', 'брикс', 'страна']

# %%
LDA = LatentDirichletAllocation(n_components=3, random_state=42)
LDA.fit(doc_term_matrix)
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['мера', 'разработка', 'важный', 'число', 'направить', 'группа', 'интерес', 'использование', 'устойчивый', 'экономический']
#
#
# Top 10 words for topic #1:
# ['подтверждать', 'призывать', 'приветствовать', 'связь', 'государство', 'оон', 'безопасность', 'усилие', 'международный', 'страна']
#
#
# Top 10 words for topic #2:
# ['решение', 'обеспечение', 'подчёркивать', 'вопрос', 'право', 'область', 'цель', 'сотрудничество', 'развитие', 'брикс']

# %% [markdown]
# Вывод: тематика декларации 2015 г. посвящена общим вопросам международного сотрудничества
