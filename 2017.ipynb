# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import string
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.probability import FreqDist
import pymorphy3

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
with open('2017.txt', 'r') as file:
    data = file.read()

# %%
stop_words = stopwords.words('russian')
morph = pymorphy3.MorphAnalyzer()

# %%
def tokenize_text(raw_text: str):
    """Функция для токенизации текста
    :param raw_text: исходная текстовая строка
    """
    # Разбиение на сслова при помощи пробела
    words = raw_text.split()
    # Подготовка регулярного выражения для фильтрации символов
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # Удаление знаков препинания
    stripped = [re_punc.sub('', w) for w in words]
    # Приведение всех слов к нижнему регистру
    words_lower = [w.lower() for w in stripped]
    # Удаление оставшихся токенов, которые не являются буквами
    words_alpha = [word for word in words_lower if word.isalpha()]
    # Удаление стоп-слов    
    words_stop = [w for w in words_alpha if not w in stop_words]
    # Лемматизация    
    tokens = [morph.parse(token)[0].normal_form for token in words_stop]
    # Удалим короткие токены
    tokens = [word for word in tokens if len(word) > 2]
      
    return tokens

# %%
tokenized = tokenize_text(data)

# %%
all_words = FreqDist(tokenized)

# %%
print("Наиболлее популярные слова: ", all_words.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words.keys()))
# Out:
# Наиболлее популярные слова:  [('брикс', 304), ('страна', 185), ('сотрудничество', 154), ('год', 129), ('встреча', 97), ('развитие', 89), ('вопрос', 73), ('также', 64), ('международный', 62), ('сфера', 55), ('цель', 54), ('область', 52), ('группа', 46), ('безопасность', 41), ('министр', 38), ('наш', 37), ('рабочий', 37), ('создание', 35), ('экономический', 34), ('форум', 33), ('вновь', 31), ('рамка', 31), ('июль', 31), ('обеспечение', 30), ('организация', 30), ('число', 29), ('подчёркивать', 29), ('поддерживать', 28), ('государство', 28), ('глобальный', 27), ('укрепление', 26), ('приветствовать', 26), ('пекин', 26), ('использование', 25), ('мир', 24), ('устойчивый', 24), ('июнь', 24), ('национальный', 23), ('который', 23), ('подтверждать', 22), ('совместный', 22), ('оон', 22), ('свой', 21), ('принцип', 21), ('отмечать', 21), ('связь', 21), ('быть', 21), ('право', 21), ('призывать', 21), ('икт', 21), ('финансовый', 20), ('роль', 20), ('торговля', 20), ('борьба', 20), ('экономика', 19), ('рынок', 19), ('другой', 19), ('партнёрство', 18), ('основа', 18), ('человек', 18), ('объединить', 18), ('нация', 18), ('технология', 18), ('действие', 18), ('рост', 17), ('усилие', 17), ('способствовать', 17), ('обмен', 17), ('повышение', 17), ('план', 17), ('взаимодействие', 16), ('включая', 16), ('банк', 16), ('посредством', 16), ('народ', 16), ('итог', 16), ('управление', 16), ('интерес', 15), ('декларация', 15), ('инициатива', 15), ('инновация', 15), ('договориться', 15), ('соответствие', 15), ('обязательство', 15), ('совет', 15), ('космический', 15), ('саммит', 14), ('общий', 14), ('взаимный', 14), ('развивающийся', 14), ('дело', 14), ('потенциал', 14), ('поддержка', 14), ('необходимость', 14), ('деловой', 14), ('важность', 14), ('региональный', 13), ('новый', 13), ('намерить', 13), ('май', 13)]
#
# Общее количество уникальных слов:  1443

# %%
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_12684\1563493910.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
stop_words_ex = ['год','наш', 'который', 'также']
def stop_words_extra(text):
    return [w for w in text if not w in stop_words_ex]

# %%
tokens = stop_words_extra(tokenized)

# %%
all_words = FreqDist(tokens)
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_12684\3051857113.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
textt = ','.join(w for w in tokens)

# %%
wordcloud = WordCloud(width=950,height=550).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Приводим текст в векторное представление
tfidf_vect = TfidfVectorizer(max_df=1.0, min_df=2, stop_words=None)
doc_term_matrix = tfidf_vect.fit_transform(tokens)

# %% [markdown]
# ### Латентное размещение Дерихле

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['организация', 'рамка', 'рабочий', 'безопасность', 'область', 'сфера', 'развитие', 'встреча', 'сотрудничество', 'страна']
#
#
# Top 10 words for topic #1:
# ['вновь', 'форум', 'экономический', 'создание', 'министр', 'группа', 'цель', 'международный', 'вопрос', 'брикс']

# %%
LDA = LatentDirichletAllocation(n_components=3, random_state=42)
LDA.fit(doc_term_matrix)
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['приветствовать', 'число', 'рабочий', 'безопасность', 'область', 'сфера', 'развитие', 'встреча', 'сотрудничество', 'страна']
#
#
# Top 10 words for topic #1:
# ['подчёркивать', 'обеспечение', 'июль', 'вновь', 'форум', 'экономический', 'создание', 'министр', 'группа', 'брикс']
#
#
# Top 10 words for topic #2:
# ['подтверждать', 'оон', 'национальный', 'мир', 'государство', 'организация', 'рамка', 'цель', 'международный', 'вопрос']

# %% [markdown]
# Вывод: тематика декларации 2017 г. посвящена общим вопросам международного сотрудничества
