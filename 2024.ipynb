# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import string
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.probability import FreqDist
import pymorphy3

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
with open('2024.txt', 'r') as file:
    data = file.read()

# %%
stop_words = stopwords.words('russian')
morph = pymorphy3.MorphAnalyzer()

# %%
def tokenize_text(raw_text: str):
    """Функция для токенизации текста
    :param raw_text: исходная текстовая строка
    """
    # Разбиение на сслова при помощи пробела
    words = raw_text.split()
    # Подготовка регулярного выражения для фильтрации символов
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # Удаление знаков препинания
    stripped = [re_punc.sub('', w) for w in words]
    # Приведение всех слов к нижнему регистру
    words_lower = [w.lower() for w in stripped]
    # Удаление оставшихся токенов, которые не являются буквами
    words_alpha = [word for word in words_lower if word.isalpha()]
    # Удаление стоп-слов    
    words_stop = [w for w in words_alpha if not w in stop_words]
    # Лемматизация    
    tokens = [morph.parse(token)[0].normal_form for token in words_stop]
    # Удалим короткие токены
    tokens = [word for word in tokens if len(word) > 2]
      
    return tokens

# %%
tokenized = tokenize_text(data)

# %%
all_words = FreqDist(tokenized)

# %%
print("Наиболлее популярные слова: ", all_words.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words.keys()))
# Out:
# Наиболлее популярные слова:  [('брикс', 235), ('страна', 165), ('развитие', 112), ('сотрудничество', 109), ('международный', 85), ('также', 80), ('область', 73), ('год', 71), ('оон', 63), ('приветствовать', 60), ('цель', 55), ('подчёркивать', 54), ('призывать', 53), ('сфера', 49), ('устойчивый', 48), ('включая', 48), ('укрепление', 46), ('обеспечение', 46), ('признать', 46), ('безопасность', 45), ('отмечать', 44), ('создание', 44), ('глобальный', 42), ('который', 42), ('роль', 41), ('число', 41), ('государство', 40), ('вопрос', 40), ('связь', 39), ('рамка', 37), ('использование', 37), ('дальнейший', 36), ('система', 36), ('усилие', 36), ('проведение', 35), ('необходимость', 35), ('национальный', 35), ('важность', 34), ('право', 31), ('решение', 30), ('мера', 30), ('обмен', 30), ('справедливый', 29), ('наш', 29), ('основа', 28), ('экономический', 28), ('потенциал', 28), ('принцип', 28), ('уровень', 28), ('важный', 28), ('вновь', 27), ('расширение', 27), ('подтверждать', 27), ('развивающийся', 27), ('поддерживать', 27), ('поддержка', 27), ('борьба', 27), ('совместный', 26), ('финансовый', 26), ('технология', 26), ('приверженность', 25), ('диалог', 25), ('возможность', 25), ('цифровой', 25), ('новый', 24), ('группа', 24), ('рынок', 23), ('механизм', 23), ('соответствие', 23), ('экономика', 22), ('принятие', 22), ('эффективный', 22), ('форум', 22), ('деятельность', 22), ('финансирование', 22), ('гуманитарный', 21), ('разработка', 21), ('платформа', 21), ('инклюзивный', 20), ('содействие', 20), ('работа', 20), ('заявлять', 19), ('участие', 19), ('климат', 19), ('инициатива', 19), ('мирный', 19), ('сохранение', 18), ('изменение', 18), ('высоко', 18), ('инфраструктура', 18), ('общий', 17), ('человек', 17), ('такой', 17), ('конференция', 17), ('африканский', 17), ('помощь', 17), ('проект', 17), ('соответствующий', 17), ('оценивать', 17), ('выражать', 17)]
#
# Общее количество уникальных слов:  1941

# %%
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_9944\1563493910.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
stop_words_ex = ['год','наш', 'который', 'также']
def stop_words_extra(text):
    return [w for w in text if not w in stop_words_ex]

# %%
tokens = stop_words_extra(tokenized)

# %%
all_words = FreqDist(tokens)
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_9944\3051857113.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
textt = ','.join(w for w in tokens)

# %%
wordcloud = WordCloud(width=950,height=550).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Приводим текст в векторное представление
tfidf_vect = TfidfVectorizer(max_df=1.0, min_df=2, stop_words=None)
doc_term_matrix = tfidf_vect.fit_transform(tokens)

# %% [markdown]
# ### Латентное размещение Дерихле

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['глобальный', 'отмечать', 'безопасность', 'обеспечение', 'включая', 'призывать', 'приветствовать', 'оон', 'страна', 'брикс']
#
#
# Top 10 words for topic #1:
# ['укрепление', 'признать', 'устойчивый', 'сфера', 'подчёркивать', 'цель', 'область', 'международный', 'сотрудничество', 'развитие']

# %%
LDA = LatentDirichletAllocation(n_components=3, random_state=42)
LDA.fit(doc_term_matrix)
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['решение', 'усилие', 'число', 'безопасность', 'обеспечение', 'призывать', 'приветствовать', 'оон', 'страна', 'брикс']
#
#
# Top 10 words for topic #1:
# ['создание', 'признать', 'укрепление', 'устойчивый', 'подчёркивать', 'цель', 'область', 'международный', 'сотрудничество', 'развитие']
#
#
# Top 10 words for topic #2:
# ['экономический', 'принцип', 'мера', 'рамка', 'использование', 'связь', 'глобальный', 'отмечать', 'включая', 'сфера']

# %% [markdown]
# Вывод: тематика декларации 2024 г. посвящена общим вопросам международного сотрудничества
