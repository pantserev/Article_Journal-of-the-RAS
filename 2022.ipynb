# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import string
import re
import nltk
nltk.download('punkt')
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
from nltk.probability import FreqDist
import pymorphy3

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.decomposition import NMF

# %%
with open('2022.txt', 'r') as file:
    data = file.read()

# %%
stop_words = stopwords.words('russian')
morph = pymorphy3.MorphAnalyzer()

# %%
def tokenize_text(raw_text: str):
    """Функция для токенизации текста
    :param raw_text: исходная текстовая строка
    """
    # Разбиение на сслова при помощи пробела
    words = raw_text.split()
    # Подготовка регулярного выражения для фильтрации символов
    re_punc = re.compile('[%s]' % re.escape(string.punctuation))
    # Удаление знаков препинания
    stripped = [re_punc.sub('', w) for w in words]
    # Приведение всех слов к нижнему регистру
    words_lower = [w.lower() for w in stripped]
    # Удаление оставшихся токенов, которые не являются буквами
    words_alpha = [word for word in words_lower if word.isalpha()]
    # Удаление стоп-слов    
    words_stop = [w for w in words_alpha if not w in stop_words]
    # Лемматизация    
    tokens = [morph.parse(token)[0].normal_form for token in words_stop]
    # Удалим короткие токены
    tokens = [word for word in tokens if len(word) > 2]
      
    return tokens

# %%
tokenized = tokenize_text(data)

# %%
all_words = FreqDist(tokenized)

# %%
print("Наиболлее популярные слова: ", all_words.most_common(100))
print("\nОбщее количество уникальных слов: ", len(all_words.keys()))
# Out:
# Наиболлее популярные слова:  [('брикс', 153), ('страна', 108), ('развитие', 93), ('сотрудничество', 90), ('область', 81), ('международный', 45), ('год', 43), ('приветствовать', 41), ('также', 40), ('устойчивый', 39), ('подчёркивать', 36), ('глобальный', 35), ('безопасность', 32), ('вопрос', 32), ('сфера', 32), ('цель', 31), ('оон', 31), ('призывать', 31), ('обеспечение', 30), ('поддерживать', 29), ('укрепление', 28), ('проведение', 28), ('отмечать', 26), ('рамка', 26), ('роль', 26), ('обмен', 25), ('подтверждать', 25), ('включая', 25), ('важность', 24), ('система', 24), ('развивающийся', 22), ('новый', 21), ('право', 21), ('экономика', 20), ('необходимость', 20), ('борьба', 20), ('приверженность', 19), ('экономический', 19), ('работа', 19), ('дальнейший', 18), ('мир', 18), ('решение', 18), ('цифровой', 18), ('поддержка', 18), ('рабочий', 18), ('государство', 17), ('организация', 17), ('совместный', 17), ('терроризм', 17), ('группа', 17), ('который', 16), ('вновь', 16), ('многосторонний', 16), ('механизм', 16), ('пандемия', 15), ('другой', 15), ('потенциал', 15), ('восстановление', 15), ('торговля', 15), ('усилие', 15), ('икт', 15), ('основа', 14), ('посредством', 14), ('рассчитывать', 14), ('число', 14), ('форум', 14), ('должный', 14), ('мера', 14), ('партнёрство', 13), ('наш', 13), ('здравоохранение', 13), ('достижение', 13), ('защита', 13), ('эффективный', 13), ('соответствие', 13), ('национальный', 13), ('вто', 13), ('признать', 13), ('соответствующий', 13), ('способствовать', 12), ('интерес', 12), ('частность', 12), ('уровень', 12), ('осуществление', 12), ('управление', 12), ('принятие', 12), ('совет', 12), ('взаимодействие', 12), ('прогресс', 12), ('направить', 12), ('взаимный', 11), ('инклюзивный', 11), ('заявлять', 11), ('содействие', 11), ('человек', 11), ('деятельность', 11), ('связь', 11), ('ведущий', 11), ('проблема', 11), ('создание', 11)]
#
# Общее количество уникальных слов:  1245

# %%
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_12060\1563493910.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
stop_words_ex = ['год','наш', 'который', 'также']
def stop_words_extra(text):
    return [w for w in text if not w in stop_words_ex]

# %%
tokens = stop_words_extra(tokenized)

# %%
all_words = FreqDist(tokens)
count, words = [], []
for w in all_words.most_common(20):
    words.append(w[0])
    count.append(w[1])
fig,ax = plt.subplots(figsize = (12,6))
ax = sns.barplot(x=words,y=count)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
ax.set_title ('Распределение частотности слов')
plt.show()
# Out:
# C:\Temp\ipykernel_12060\3051857113.py:8: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45)

# %%
textt = ','.join(w for w in tokens)

# %%
wordcloud = WordCloud(width=950,height=550).generate(textt)
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
# Приводим текст в векторное представление
tfidf_vect = TfidfVectorizer(max_df=1.0, min_df=2, stop_words=None)
doc_term_matrix = tfidf_vect.fit_transform(tokens)

# %% [markdown]
# ### Латентное размещение Дерихле

# %%
LDA = LatentDirichletAllocation(n_components=2, random_state=42)
LDA.fit(doc_term_matrix)
# Out:
# LatentDirichletAllocation(n_components=2, random_state=42)

# %%
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['цель', 'оон', 'призывать', 'вопрос', 'глобальный', 'устойчивый', 'приветствовать', 'международный', 'развитие', 'страна']
#
#
# Top 10 words for topic #1:
# ['отмечать', 'проведение', 'укрепление', 'обеспечение', 'сфера', 'безопасность', 'подчёркивать', 'область', 'сотрудничество', 'брикс']

# %%
LDA = LatentDirichletAllocation(n_components=3, random_state=42)
LDA.fit(doc_term_matrix)
for i,topic in enumerate(LDA.components_):
    print(f'Top 10 words for topic #{i}:')
    print([tfidf_vect.get_feature_names_out()[i] for i in topic.argsort()[-10:]])
    print('\n')
# Out:
# Top 10 words for topic #0:
# ['экономика', 'важность', 'роль', 'цель', 'оон', 'вопрос', 'устойчивый', 'приветствовать', 'международный', 'развитие']
#
#
# Top 10 words for topic #1:
# ['подтверждать', 'включая', 'отмечать', 'рамка', 'укрепление', 'обеспечение', 'безопасность', 'область', 'сотрудничество', 'брикс']
#
#
# Top 10 words for topic #2:
# ['решение', 'экономический', 'новый', 'проведение', 'поддерживать', 'призывать', 'сфера', 'глобальный', 'подчёркивать', 'страна']

# %% [markdown]
# Вывод: тематика декларации 2022 г. посвящена общим вопросам международного сотрудничества
